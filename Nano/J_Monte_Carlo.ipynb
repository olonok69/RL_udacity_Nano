# %% [markdown]
# # Monte Carlo Methods
#
# In this notebook, you will write your own implementations of many Monte Carlo (MC) algorithms.
#
# While we have provided some starter code, you are welcome to erase these hints and write your code from scratch.
#
# ### Part 0: Explore BlackjackEnv
#
# We begin by importing the necessary packages.

# %%
import sys
import gym
import numpy as np
from collections import defaultdict

from plot_utils import plot_blackjack_values, plot_policy

# %% [markdown]
# Use the code cell below to create an instance of the [Blackjack](https://github.com/openai/gym/blob/master/gym/envs/toy_text/blackjack.py) environment.

# %%
env = gym.make('Blackjack-v0')

# %% [markdown]
# Each state is a 3-tuple of:
# - the player's current sum $\in \{0, 1, \ldots, 31\}$,
# - the dealer's face up card $\in \{1, \ldots, 10\}$, and
# - whether or not the player has a usable ace (`no` $=0$, `yes` $=1$).
#
# The agent has two potential actions:
#
# ```
#     STICK = 0
#     HIT = 1
# ```
# Verify this by running the code cell below.

# %%
print(env.observation_space)
print(env.action_space)
# Out:
# Tuple(Discrete(32), Discrete(11), Discrete(2))
# Discrete(2)

# %% [markdown]
# Execute the code cell below to play Blackjack with a random policy.
#
# (_The code currently plays Blackjack three times - feel free to change this number, or to run the cell multiple times.  The cell is designed for you to get some experience with the output that is returned as the agent interacts with the environment._)

# %%
env.action_space.n, env.observation_space.to_jsonable
# Out:
# (2,
#  <bound method Tuple.to_jsonable of Tuple(Discrete(32), Discrete(11), Discrete(2))>)

# %%
for i_episode in range(3):
    state = env.reset()
    while True:
        
        action = env.action_space.sample()
        print(action)
        state, reward, done, info = env.step(action)
        print(state)
        if done:
            print('End game! Reward: ', reward)
            print('You won :)\n') if reward > 0 else print('You lost :(\n')
            break
# Out:
# 0
# (18, 7, False)
# End game! Reward:  1.0
# You won :)
#
# 1
# (25, 10, False)
# End game! Reward:  -1
# You lost :(
#
# 1
# (17, 10, False)
# 0
# (17, 10, False)
# End game! Reward:  -1.0
# You lost :(

# %% [markdown]
# ### Part 1: MC Prediction
#
# In this section, you will write your own implementation of MC prediction (for estimating the action-value function).
#
# We will begin by investigating a policy where the player _almost_ always sticks if the sum of her cards exceeds 18.  In particular, she selects action `STICK` with 80% probability if the sum is greater than 18; and, if the sum is 18 or below, she selects action `HIT` with 80% probability.  The function `generate_episode_from_limit_stochastic` samples an episode using this policy.
#
# The function accepts as **input**:
# - `bj_env`: This is an instance of OpenAI Gym's Blackjack environment.
#
# It returns as **output**:
# - `episode`: This is a list of (state, action, reward) tuples (of tuples) and corresponds to $(S_0, A_0, R_1, \ldots, S_{T-1}, A_{T-1}, R_{T})$, where $T$ is the final time step.  In particular, `episode[i]` returns $(S_i, A_i, R_{i+1})$, and `episode[i][0]`, `episode[i][1]`, and `episode[i][2]` return $S_i$, $A_i$, and $R_{i+1}$, respectively.

# %%
def generate_episode_from_limit_stochastic(bj_env):
    episode = []
    state = bj_env.reset()
    while True:
        probs = [0.8, 0.2] if state[0] > 18 else [0.2, 0.8]
        action = np.random.choice(np.arange(2), p=probs)
        next_state, reward, done, info = bj_env.step(action)
        episode.append((state, action, reward))
        state = next_state
        if done:
            break
    return episode

# %% [markdown]
# Execute the code cell below to play Blackjack with the policy.
#
# (*The code currently plays Blackjack three times - feel free to change this number, or to run the cell multiple times.  The cell is designed for you to gain some familiarity with the output of the `generate_episode_from_limit_stochastic` function.*)

# %% [markdown]
# Each state is a 3-tuple of:
# - the player's current sum $\in \{0, 1, \ldots, 31\}$,
# - the dealer's face up card $\in \{1, \ldots, 10\}$, and
# - whether or not the player has a usable ace (`no` $=0$, `yes` $=1$).
#
# The agent has two potential actions:
#
# ```
#     STICK = 0
#     HIT = 1
# ```
# Verify this by running the code cell below.

# %%
for i in range(3):
    print(generate_episode_from_limit_stochastic(env))
# Out:
# [((17, 6, False), 0, -1.0)]
# [((12, 1, False), 1, -1)]
# [((12, 10, False), 1, 0), ((14, 10, False), 1, -1)]

# %% [markdown]
# Now, you are ready to write your own implementation of MC prediction.  Feel free to implement either first-visit or every-visit MC prediction; in the case of the Blackjack environment, the techniques are equivalent.
#
# Your algorithm has three arguments:
# - `env`: This is an instance of an OpenAI Gym environment.
# - `num_episodes`: This is the number of episodes that are generated through agent-environment interaction.
# - `generate_episode`: This is a function that returns an episode of interaction.
# - `gamma`: This is the discount rate.  It must be a value between 0 and 1, inclusive (default value: `1`).
#
# The algorithm returns as output:
# - `Q`: This is a dictionary (of one-dimensional arrays) where `Q[s][a]` is the estimated action value corresponding to state `s` and action `a`.

# %%
def mc_prediction_q(env, num_episodes, generate_episode, gamma=1.0):
    # initialize empty dictionaries of arrays
    returns_sum = defaultdict(lambda: np.zeros(env.action_space.n))
    N = defaultdict(lambda: np.zeros(env.action_space.n))
    Q = defaultdict(lambda: np.zeros(env.action_space.n))
    # loop over episodes
    for i_episode in range(1, num_episodes+1):
        # monitor progress
        if i_episode % 1000 == 0:
            print("\rEpisode {}/{}.".format(i_episode, num_episodes), end="")
            sys.stdout.flush()
        
        # generate an episode
        episode = generate_episode(env)
        #print(episode)
        # obtain the states, actions, and rewards
        states, actions, rewards = zip(*episode)
        #print(actions)
        # prepare for discounting
        discounts = np.array([gamma**i for i in range(len(rewards)+1)])
        #print(discounts)
        # update the sum of the returns, number of visits, and action-value 
        # function estimates for each state-action pair in the episode
        for i, state in enumerate(states):
            returns_sum[state][actions[i]] += sum(rewards[i:]*discounts[:-(1+i)])
            N[state][actions[i]] += 1.0
            Q[state][actions[i]] = returns_sum[state][actions[i]] / N[state][actions[i]]        
    return Q, returns_sum, N

# %% [markdown]
# Use the cell below to obtain the action-value function estimate $Q$.  We have also plotted the corresponding state-value function.
#
# To check the accuracy of your implementation, compare the plot below to the corresponding plot in the solutions notebook **Monte_Carlo_Solution.ipynb**.

# %%
Q, returns_sum, N = mc_prediction_q(env, 10, generate_episode_from_limit_stochastic)

# %%
Q.keys()
# Out:
# dict_keys([(15, 5, False), (16, 5, False), (21, 5, False), (11, 10, False), (12, 10, False), (12, 5, False), (16, 10, False), (4, 10, False), (14, 10, False), (17, 10, False), (20, 10, False), (9, 4, False), (18, 10, False), (21, 10, False), (20, 8, False)])

# %%
returns_sum.keys()
# Out:
# dict_keys([(15, 5, False), (16, 5, False), (21, 5, False), (11, 10, False), (12, 10, False), (12, 5, False), (16, 10, False), (4, 10, False), (14, 10, False), (17, 10, False), (20, 10, False), (9, 4, False), (18, 10, False), (21, 10, False), (20, 8, False)])

# %%
N.keys()
# Out:
# dict_keys([(15, 5, False), (16, 5, False), (21, 5, False), (11, 10, False), (12, 10, False), (12, 5, False), (16, 10, False), (4, 10, False), (14, 10, False), (17, 10, False), (20, 10, False), (9, 4, False), (18, 10, False), (21, 10, False), (20, 8, False)])

# %%
for key in Q.keys():
    print(f"key {key} value {Q[key]}")
# Out:
# key (15, 5, False) value [-1.  1.]
# key (16, 5, False) value [ 0.  1.]
# key (21, 5, False) value [ 1.  0.]
# key (11, 10, False) value [ 0. -1.]
# key (12, 10, False) value [ 0. -1.]
# key (12, 5, False) value [ 0. -1.]
# key (16, 10, False) value [ 0.  0.]
# key (4, 10, False) value [ 0. -1.]
# key (14, 10, False) value [ 0.  0.]
# key (17, 10, False) value [ 0.  1.]
# key (20, 10, False) value [ 1.  0.]
# key (9, 4, False) value [-1.  0.]
# key (18, 10, False) value [ 0. -1.]
# key (21, 10, False) value [ 1.  0.]
# key (20, 8, False) value [ 0. -1.]

# %%
returns_sum[(17, 6, False)]
# Out:
# array([ 0.,  0.])

# %%
N[(17, 6, False)]
# Out:
# array([ 0.,  0.])

# %%
# obtain the action-value function
Q, returns_sum, N = mc_prediction_q(env, 500000, generate_episode_from_limit_stochastic)

# obtain the corresponding state-value function
V_to_plot = dict((k,(k[0]>18)*(np.dot([0.8, 0.2],v)) + (k[0]<=18)*(np.dot([0.2, 0.8],v))) \
         for k, v in Q.items())

# plot the state-value function
plot_blackjack_values(V_to_plot)
# Out:
# Episode 500000/500000.

# %%
for key in Q.keys():
    print(f"key {key} value {Q[key]}")
# Out:
# key (16, 5, False) value [-0.15269805 -0.6145688 ]
# key (18, 5, False) value [ 0.19117647 -0.69872506]
# key (14, 10, False) value [-0.58582807 -0.62334554]
# key (19, 10, True) value [-0.04951742 -0.30578512]
# key (20, 10, True) value [ 0.44377267 -0.27312775]
# key (7, 8, False) value [-0.48502994 -0.42489851]
# key (13, 5, False) value [-0.15704388 -0.4865504 ]
# key (17, 5, False) value [-0.02004454 -0.64150433]
# key (8, 5, False) value [-0.12605042 -0.3657754 ]
# key (13, 2, False) value [-0.28834356 -0.51809305]
# key (19, 2, False) value [ 0.3994882  -0.78121547]
# key (18, 10, True) value [-0.22368421 -0.37859712]
# key (13, 1, False) value [-0.77477477 -0.66745214]
# key (17, 9, False) value [-0.45444444 -0.65317287]
# key (12, 3, False) value [-0.24337349 -0.4706051 ]
# key (9, 10, False) value [-0.56336877 -0.4131072 ]
# key (19, 10, False) value [-0.03362583 -0.80714286]
# key (20, 10, False) value [ 0.43018153 -0.88614158]
# key (15, 10, True) value [-0.55353075 -0.32481954]
# key (16, 6, True) value [-0.10743802 -0.08351178]
# key (18, 6, True) value [ 0.27338129 -0.23741007]
# key (18, 6, False) value [ 0.28       -0.66264068]
# key (10, 5, False) value [-0.2125     -0.02612994]
# key (17, 4, False) value [-0.10364465 -0.64805087]
# key (10, 10, False) value [-0.58767123 -0.23914923]
# key (14, 5, False) value [-0.17471264 -0.5018315 ]
# key (14, 1, False) value [-0.7416577  -0.67685835]
# key (15, 2, False) value [-0.28044693 -0.6040079 ]
# key (15, 4, False) value [-0.20134983 -0.57936726]
# key (14, 2, False) value [-0.32013201 -0.54414669]
# key (20, 8, True) value [ 0.80833333 -0.09150327]
# key (12, 10, False) value [-0.57419728 -0.54565217]
# key (17, 10, False) value [-0.45643267 -0.69726979]
# key (4, 7, False) value [-0.34782609 -0.39698492]
# key (19, 1, False) value [-0.1222885 -0.796875 ]
# key (20, 7, True) value [ 0.7804878  -0.07894737]
# key (19, 7, False) value [ 0.62625394 -0.76318875]
# key (20, 2, False) value [ 0.64309898 -0.86850394]
# key (8, 9, False) value [-0.5371179  -0.46729958]
# key (12, 6, False) value [-0.10872162 -0.44203111]
# key (16, 6, False) value [-0.16043956 -0.60187287]
# key (10, 3, False) value [-0.25842697 -0.06647808]
# key (12, 2, False) value [-0.32447398 -0.4639235 ]
# key (17, 2, False) value [-0.15682062 -0.66648472]
# key (18, 7, False) value [ 0.38648363 -0.68516453]
# key (18, 10, False) value [-0.22265087 -0.72844238]
# key (20, 4, False) value [ 0.6517502  -0.88933121]
# key (11, 10, False) value [-0.5643454  -0.16995291]
# key (20, 5, False) value [ 0.66093906 -0.90375204]
# key (17, 3, False) value [-0.1375948  -0.64434565]
# key (21, 10, True) value [ 0.88673412 -0.19252232]
# key (17, 1, False) value [-0.60836084 -0.7558107 ]
# key (13, 7, False) value [-0.47065593 -0.49035187]
# key (21, 7, False) value [ 0.9284738 -1.       ]
# key (21, 10, False) value [ 0.88304358 -1.        ]
# key (21, 1, True) value [ 0.63452656 -0.25295508]
# key (10, 8, False) value [-0.53296703 -0.01675978]
# key (17, 1, True) value [-0.57142857 -0.47859922]
# key (11, 8, False) value [-0.50984683 -0.07081668]
# key (21, 8, False) value [ 0.93067979 -1.        ]
# key (18, 4, False) value [ 0.16345062 -0.70568928]
# key (13, 6, False) value [-0.10960452 -0.47101857]
# key (17, 6, False) value [ 0.00417101 -0.63283666]
# key (16, 10, False) value [-0.56545807 -0.67421603]
# key (16, 1, False) value [-0.73854749 -0.71567538]
# key (16, 8, False) value [-0.50711939 -0.59460219]
# key (20, 8, False) value [ 0.78869828 -0.88753056]
# key (9, 9, False) value [-0.51746032 -0.23477493]
# key (16, 9, False) value [-0.56456777 -0.6445616 ]
# key (20, 3, False) value [ 0.65031274 -0.88810087]
# key (12, 1, False) value [-0.78450363 -0.63174333]
# key (17, 10, True) value [-0.47689464 -0.38692494]
# key (11, 7, False) value [-0.45995423 -0.03147432]
# key (21, 1, False) value [ 0.62909091 -1.        ]
# key (15, 3, False) value [-0.25485714 -0.60005613]
# key (13, 9, False) value [-0.55581128 -0.50965909]
# key (14, 9, False) value [-0.54962647 -0.55678278]
# key (4, 3, False) value [-0.36170213 -0.38311688]
# key (16, 3, False) value [-0.27936146 -0.6132287 ]
# key (14, 8, False) value [-0.50233645 -0.51704217]
# key (15, 10, False) value [-0.60613668 -0.64316657]
# key (13, 8, False) value [-0.48460661 -0.49085546]
# key (9, 3, False) value [-0.16065574 -0.210139  ]
# key (19, 3, False) value [ 0.39015573 -0.76726058]
# key (12, 4, False) value [-0.15673289 -0.45710102]
# key (21, 4, False) value [ 0.89431258 -1.        ]
# key (10, 2, False) value [-0.3819242  -0.08100559]
# key (13, 7, True) value [-0.48717949 -0.16666667]
# key (19, 7, True) value [ 0.64586583  0.08641975]
# key (17, 7, False) value [-0.07112527 -0.62144847]
# key (18, 3, False) value [ 0.16815145 -0.69595344]
# key (12, 5, False) value [-0.18139535 -0.44305636]
# key (19, 6, False) value [ 0.50966851 -0.75936436]
# key (19, 9, False) value [ 0.2799435  -0.73948598]
# key (12, 8, False) value [-0.54634146 -0.47502904]
# key (21, 5, True) value [ 0.8984375  -0.11805556]
# key (19, 8, False) value [ 0.60480094 -0.78571429]
# key (20, 6, False) value [ 0.70656821 -0.88627132]
# key (13, 5, True) value [-0.22580645 -0.1446384 ]
# key (15, 5, True) value [ 0.09803922 -0.2       ]
# key (15, 5, False) value [-0.28193326 -0.59029957]
# key (19, 5, False) value [ 0.45931232 -0.7579758 ]
# key (9, 2, False) value [-0.29903537 -0.21781305]
# key (20, 2, True) value [ 0.66282895 -0.08235294]
# key (11, 2, False) value [-0.31742243 -0.11736527]
# key (21, 2, False) value [ 0.88561215 -1.        ]
# key (18, 2, False) value [ 0.13585746 -0.70478001]
# key (19, 1, True) value [-0.1        -0.40963855]
# key (10, 7, False) value [-0.40700809 -0.05521049]
# key (12, 7, False) value [-0.41695703 -0.44868871]
# key (10, 6, False) value [-0.13529412 -0.0807666 ]
# key (12, 6, True) value [ 0.21212121  0.        ]
# key (17, 6, True) value [ 0.03676471 -0.20849421]
# key (21, 8, True) value [ 0.93236715 -0.07281553]
# key (15, 8, False) value [-0.50751445 -0.57004964]
# key (16, 1, True) value [-0.8317757 -0.4665272]
# key (20, 1, True) value [ 0.16875   -0.1971831]
# key (9, 1, False) value [-0.78985507 -0.49758065]
# key (4, 10, False) value [-0.58169935 -0.52336449]
# key (14, 6, False) value [-0.13425926 -0.52293836]
# key (13, 9, True) value [-0.53191489 -0.16389549]
# key (16, 9, True) value [-0.49056604 -0.28085106]
# key (18, 9, False) value [-0.06717226 -0.70548899]
# key (6, 10, False) value [-0.57876106 -0.55489478]
# key (7, 7, False) value [-0.40566038 -0.40608466]
# key (11, 9, False) value [-0.56404494 -0.08445748]
# key (18, 1, False) value [-0.34787472 -0.76740377]
# key (20, 9, False) value [ 0.7666401  -0.89352989]
# key (14, 7, False) value [-0.50056497 -0.5       ]
# key (15, 7, False) value [-0.46849943 -0.54171301]
# key (6, 7, False) value [-0.46969697 -0.4       ]
# key (16, 7, False) value [-0.51052049 -0.60953966]
# key (19, 5, True) value [ 0.42713568 -0.00684932]
# key (14, 3, False) value [-0.22747748 -0.5313914 ]
# key (16, 4, False) value [-0.24861878 -0.60664584]
# key (7, 10, False) value [-0.52763819 -0.55157093]
# key (20, 1, False) value [ 0.15841187 -0.9000793 ]
# key (21, 4, True) value [ 0.88452915  0.00524934]
# key (11, 3, False) value [-0.19362187 -0.06813063]
# key (20, 4, True) value [ 0.6197411  -0.10650888]
# key (19, 4, False) value [ 0.43683918 -0.79077615]
# key (13, 3, False) value [-0.29512195 -0.50268741]
# key (21, 3, False) value [ 0.89637781 -1.        ]
# key (21, 9, False) value [ 0.93922652 -1.        ]
# key (8, 3, False) value [-0.23137255 -0.4284141 ]
# key (13, 10, False) value [-0.56951948 -0.59445971]
# key (16, 4, True) value [-0.20353982 -0.22641509]
# key (19, 4, True) value [ 0.37868852 -0.15172414]
# key (8, 7, False) value [-0.53773585 -0.33802817]
# key (13, 10, True) value [-0.58746736 -0.29711603]
# key (16, 10, True) value [-0.55357143 -0.3785558 ]
# key (18, 8, True) value [ 0.15555556 -0.26132404]
# key (19, 8, True) value [ 0.58093525 -0.17567568]
# key (9, 6, False) value [-0.26045016 -0.07397959]
# key (15, 9, False) value [-0.57111597 -0.59836987]
# key (20, 7, False) value [ 0.76835937 -0.8748019 ]
# key (15, 1, False) value [-0.78913043 -0.69285911]
# key (10, 9, False) value [-0.55489614 -0.1049936 ]
# key (6, 3, False) value [-0.20567376 -0.40909091]
# key (11, 6, False) value [-0.03225806 -0.00917431]
# key (13, 8, True) value [-0.70666667 -0.1634349 ]
# key (16, 8, True) value [-0.49514563 -0.30932203]
# key (11, 1, False) value [-0.78095238 -0.30005907]
# key (7, 4, False) value [-0.2       -0.3847185]
# key (7, 9, False) value [-0.58024691 -0.43624161]
# key (21, 7, True) value [ 0.92044785 -0.06053812]
# key (17, 4, True) value [-0.07874016 -0.27938343]
# key (5, 10, False) value [-0.59779614 -0.54258242]
# key (21, 6, True) value [ 0.90022676 -0.125     ]
# key (18, 8, False) value [ 0.10772579 -0.68843946]
# key (14, 10, True) value [-0.60406091 -0.31883157]
# key (13, 4, False) value [-0.22551253 -0.48607081]
# key (21, 2, True) value [ 0.89041882 -0.16009281]
# key (17, 8, False) value [-0.41822173 -0.64005487]
# key (8, 8, False) value [-0.51754386 -0.39842209]
# key (13, 4, True) value [-0.06493506 -0.13114754]
# key (21, 9, True) value [ 0.93226177 -0.16704289]
# key (4, 2, False) value [-0.45       -0.41706161]
# key (5, 6, False) value [-0.13953488 -0.36939314]
# key (6, 4, False) value [-0.21666667 -0.39892665]
# key (21, 3, True) value [ 0.87695879 -0.03628118]
# key (17, 8, True) value [-0.28455285 -0.32790224]
# key (18, 9, True) value [-0.25503356 -0.35638298]
# key (9, 4, False) value [-0.23448276 -0.19173554]
# key (8, 10, False) value [-0.58317025 -0.53590874]
# key (14, 4, False) value [-0.18259023 -0.52389277]
# key (5, 5, False) value [-0.04950495 -0.33923304]
# key (9, 7, False) value [-0.52024922 -0.13227092]
# key (6, 8, False) value [-0.53731343 -0.48667851]
# key (15, 2, True) value [-0.25233645 -0.20697674]
# key (18, 7, True) value [ 0.38931298 -0.15714286]
# key (16, 5, True) value [-0.20634921 -0.22292994]
# key (9, 8, False) value [-0.51791531 -0.15733982]
# key (14, 3, True) value [-0.25925926 -0.13414634]
# key (16, 2, False) value [-0.33564014 -0.62684901]
# key (21, 6, False) value [ 0.89910714 -1.        ]
# key (7, 5, False) value [-0.25714286 -0.35900963]
# key (11, 5, False) value [-0.15165877 -0.05312869]
# key (8, 4, False) value [-0.16129032 -0.41031149]
# key (10, 4, False) value [-0.17548747 -0.06785714]
# key (18, 4, True) value [ 0.30344828 -0.26984127]
# key (14, 7, True) value [-0.4954955 -0.1382716]
# key (18, 2, True) value [ 0.08783784 -0.26335878]
# key (14, 2, True) value [-0.38461538 -0.15025907]
# key (17, 2, True) value [-0.28333333 -0.27162978]
# key (18, 5, True) value [ 0.26751592 -0.31046931]
# key (12, 9, False) value [-0.57352941 -0.49269006]
# key (4, 6, False) value [-0.15555556 -0.215     ]
# key (10, 1, False) value [-0.75074184 -0.38810007]
# key (18, 1, True) value [-0.30612245 -0.46958175]
# key (11, 4, False) value [-0.24205379 -0.08477509]
# key (8, 1, False) value [-0.78448276 -0.61105627]
# key (15, 6, False) value [-0.15681818 -0.56786315]
# key (21, 5, False) value [ 0.88617886 -1.        ]
# key (12, 10, True) value [-0.60846561 -0.23626374]
# key (7, 1, False) value [-0.73056995 -0.644     ]
# key (5, 3, False) value [-0.27835052 -0.36936937]
# key (6, 9, False) value [-0.47169811 -0.46945338]
# key (6, 6, False) value [-0.15107914 -0.28409091]
# key (12, 7, True) value [-0.62264151 -0.18965517]
# key (15, 1, True) value [-0.66666667 -0.48899756]
# key (7, 3, False) value [-0.32222222 -0.40364583]
# key (14, 5, True) value [-0.23255814 -0.06345178]
# key (15, 4, True) value [-0.14       -0.12244898]
# key (9, 5, False) value [-0.2852459  -0.13684211]
# key (17, 5, True) value [ 0.01652893 -0.16129032]
# key (7, 6, False) value [-0.18324607 -0.34255599]
# key (6, 2, False) value [-0.31578947 -0.37962963]
# key (17, 7, True) value [-0.12295082 -0.25468165]
# key (4, 1, False) value [-0.74468085 -0.65317919]
# key (6, 5, False) value [-0.27659574 -0.4351145 ]
# key (20, 6, True) value [ 0.64552846 -0.04444444]
# key (13, 1, True) value [-0.80246914 -0.45054945]
# key (5, 1, False) value [-0.75       -0.65819209]
# key (13, 3, True) value [-0.22807018 -0.17708333]
# key (5, 4, False) value [-0.20481928 -0.36657682]
# key (8, 6, False) value [-0.27118644 -0.38238238]
# key (14, 8, True) value [-0.59139785 -0.12605042]
# key (8, 2, False) value [-0.33333333 -0.38349007]
# key (14, 4, True) value [-0.24770642 -0.19      ]
# key (4, 8, False) value [-0.49090909 -0.33529412]
# key (15, 3, True) value [-0.05263158 -0.3030303 ]
# key (18, 3, True) value [ 0.0620155  -0.27464789]
# key (5, 8, False) value [-0.45054945 -0.51232877]
# key (16, 7, True) value [-0.4        -0.23298969]
# key (12, 3, True) value [-0.15384615 -0.05882353]
# key (14, 6, True) value [-0.32075472 -0.09069212]
# key (17, 3, True) value [-0.00704225 -0.17032967]
# key (15, 9, True) value [-0.49180328 -0.28978622]
# key (20, 9, True) value [ 0.71362229 -0.01226994]
# key (19, 9, True) value [ 0.31686542 -0.19480519]
# key (16, 3, True) value [-0.453125   -0.18787879]
# key (16, 2, True) value [-0.25233645 -0.30526316]
# key (7, 2, False) value [-0.29648241 -0.37615894]
# key (14, 1, True) value [-0.77777778 -0.44854881]
# key (20, 5, True) value [ 0.6618123  -0.13939394]
# key (12, 5, True) value [-0.25714286 -0.09424084]
# key (20, 3, True) value [ 0.63593005 -0.14634146]
# key (5, 2, False) value [-0.20792079 -0.42432432]
# key (17, 9, True) value [-0.52777778 -0.28922495]
# key (19, 6, True) value [ 0.56466877  0.09375   ]
# key (12, 8, True) value [-0.42222222 -0.13636364]
# key (12, 4, True) value [-0.14893617  0.04972376]
# key (19, 3, True) value [ 0.44073456 -0.125     ]
# key (15, 7, True) value [-0.5047619  -0.18097448]
# key (12, 9, True) value [-0.36170213 -0.2513369 ]
# key (13, 6, True) value [-0.12941176 -0.05322129]
# key (19, 2, True) value [ 0.36075949 -0.1656051 ]
# key (15, 8, True) value [-0.65217391 -0.1558753 ]
# key (15, 6, True) value [-0.26213592 -0.08045977]
# key (5, 7, False) value [-0.44578313 -0.3852459 ]
# key (4, 4, False) value [-0.19047619 -0.35025381]
# key (13, 2, True) value [-0.16504854 -0.16193182]
# key (12, 2, True) value [-0.1372549  -0.08383234]
# key (4, 5, False) value [ 0.         -0.44021739]
# key (6, 1, False) value [-0.73239437 -0.61578947]
# key (12, 1, True) value [-0.73913043 -0.49450549]
# key (5, 9, False) value [-0.52631579 -0.45224719]
# key (14, 9, True) value [-0.47169811 -0.25729443]
# key (4, 9, False) value [-0.54545455 -0.52717391]

# %%
V_to_plot
# Out:
# {(16, 5, False): -0.52219464732201082,
#  (18, 5, False): -0.52074475022825095,
#  (14, 10, False): -0.61584204301723133,
#  (19, 10, True): -0.10077095681185255,
#  (20, 10, True): 0.30039258718684914,
#  (7, 8, False): -0.43692479722557598,
#  (13, 5, False): -0.42064909522479943,
#  (17, 5, False): -0.51721237188943203,
#  (8, 5, False): -0.31783040488922848,
#  (13, 2, False): -0.47214315163346648,
#  (19, 2, False): 0.16334746621382801,
#  (18, 10, True): -0.34761453994698976,
#  (13, 1, False): -0.68891666334965296,
#  (17, 9, False): -0.61342718210551916,
#  (12, 3, False): -0.42515878253478495,
#  (9, 10, False): -0.44315951521028418,
#  (19, 10, False): -0.18832923832923837,
#  (20, 10, False): 0.16691690736686809,
#  (15, 10, True): -0.37056178609959789,
#  (16, 6, True): -0.088297025147326888,
#  (18, 6, True): -0.13525179856115108,
#  (18, 6, False): -0.47411254460609392,
#  (10, 5, False): -0.063403954802259882,
#  (17, 4, False): -0.53916962609494656,
#  (10, 10, False): -0.30885363097790169,
#  (14, 5, False): -0.43640773020083368,
#  (14, 1, False): -0.68981821530638898,
#  (15, 2, False): -0.53929570780057301,
#  (15, 4, False): -0.50376377643303527,
#  (14, 2, False): -0.49934375101826123,
#  (20, 8, True): 0.62836601307189544,
#  (12, 10, False): -0.55136119530630978,
#  (17, 10, False): -0.64910236483222628,
#  (4, 7, False): -0.38715315708979681,
#  (19, 1, False): -0.25720580260303694,
#  (20, 7, True): 0.60860077021822856,
#  (19, 7, False): 0.34836540364508517,
#  (20, 2, False): 0.34077840001129123,
#  (8, 9, False): -0.48126324323328362,
#  (12, 6, False): -0.37536921490262337,
#  (16, 6, False): -0.51358620947724243,
#  (10, 3, False): -0.10486785436168017,
#  (12, 2, False): -0.43603359547507858,
#  (17, 2, False): -0.56455189752297152,
#  (18, 7, False): -0.47083489647349697,
#  (18, 10, False): -0.62728407450491031,
#  (20, 4, False): 0.34353391707077319,
#  (11, 10, False): -0.2488314115627577,
#  (20, 5, False): 0.34800084092090622,
#  (17, 3, False): -0.54299548116923058,
#  (21, 10, True): 0.67088283194812492,
#  (17, 1, False): -0.72632072504366096,
#  (13, 7, False): -0.48641268356781514,
#  (21, 7, False): 0.54277904328018223,
#  (21, 10, False): 0.50643486114247005,
#  (21, 1, True): 0.45703023056470055,
#  (10, 8, False): -0.12000122782245688,
#  (17, 1, True): -0.49716509171762091,
#  (11, 8, False): -0.15862270637472553,
#  (21, 8, False): 0.54454382826475856,
#  (18, 4, False): -0.53186129746135913,
#  (13, 6, False): -0.39873576045452097,
#  (17, 6, False): -0.50543512579140903,
#  (16, 10, False): -0.65246443591714398,
#  (16, 1, False): -0.72024979737346329,
#  (16, 8, False): -0.57710563161481254,
#  (20, 8, False): 0.45345251517940188,
#  (9, 9, False): -0.29131201053531153,
#  (16, 9, False): -0.62856283247476719,
#  (20, 3, False): 0.34263002210035298,
#  (12, 1, False): -0.66229538851604519,
#  (17, 10, True): -0.40491887948512528,
#  (11, 7, False): -0.1171703055444291,
#  (21, 1, False): 0.3032727272727273,
#  (15, 3, False): -0.53101633454953701,
#  (13, 9, False): -0.51888952819332568,
#  (14, 9, False): -0.55535151835533847,
#  (4, 3, False): -0.37883393202542143,
#  (16, 3, False): -0.54645525154547459,
#  (14, 8, False): -0.51410102744348529,
#  (15, 10, False): -0.63576059492653469,
#  (13, 8, False): -0.48960568847270297,
#  (9, 3, False): -0.20024234950337122,
#  (19, 3, False): 0.15867246705693777,
#  (12, 4, False): -0.39702739827859823,
#  (21, 4, False): 0.51545006717420505,
#  (10, 2, False): -0.14118930892388881,
#  (13, 7, True): -0.23076923076923078,
#  (19, 7, True): 0.53397661832399224,
#  (17, 7, False): -0.51138382745181532,
#  (18, 3, False): -0.52313245991338231,
#  (12, 5, False): -0.39072415983135822,
#  (19, 6, False): 0.25586193489317144,
#  (19, 9, False): 0.076057605998204741,
#  (12, 8, False): -0.48929152148664345,
#  (21, 5, True): 0.69513888888888886,
#  (19, 8, False): 0.32669789227166274,
#  (20, 6, False): 0.38800030182836642,
#  (13, 5, True): -0.16087201351460062,
#  (15, 5, True): -0.14039215686274514,
#  (15, 5, False): -0.52862630895531459,
#  (19, 5, False): 0.21585469721757278,
#  (9, 2, False): -0.23405751487209153,
#  (20, 2, True): 0.51379256965944275,
#  (11, 2, False): -0.15737670244237065,
#  (21, 2, False): 0.50848972296693473,
#  (18, 2, False): -0.53665251648602907,
#  (19, 1, True): -0.16192771084337351,
#  (10, 7, False): -0.1255700092451528,
#  (12, 7, False): -0.44234237455585174,
#  (10, 6, False): -0.091672102105729347,
#  (12, 6, True): 0.042424242424242427,
#  (17, 6, True): -0.15944242561889621,
#  (21, 8, True): 0.73133061301064684,
#  (15, 8, False): -0.55754260335598071,
#  (16, 1, True): -0.53957689750909166,
#  (20, 1, True): 0.095563380281690147,
#  (9, 1, False): -0.5560355306217859,
#  (4, 10, False): -0.53503145806609242,
#  (14, 6, False): -0.44520254140997179,
#  (13, 9, True): -0.23749936827209783,
#  (16, 9, True): -0.32279405861099963,
#  (18, 9, False): -0.57782564819010296,
#  (6, 10, False): -0.55966804038572093,
#  (7, 7, False): -0.40599980033942307,
#  (11, 9, False): -0.18037497116873702,
#  (18, 1, False): -0.68349795799460233,
#  (20, 9, False): 0.4346060978185331,
#  (14, 7, False): -0.50011299435028256,
#  (15, 7, False): -0.52707029702087216,
#  (6, 7, False): -0.413939393939394,
#  (16, 7, False): -0.5897358223558743,
#  (19, 5, True): 0.34033867969986925,
#  (14, 3, False): -0.47060861766744122,
#  (16, 4, False): -0.53504042830624776,
#  (7, 10, False): -0.54678438208178315,
#  (20, 1, False): -0.053286363736833958,
#  (21, 4, True): 0.70867318715205452,
#  (11, 3, False): -0.093228878080814301,
#  (20, 4, True): 0.4744911051109707,
#  (19, 4, False): 0.19131611052792022,
#  (13, 3, False): -0.46117431952254456,
#  (21, 3, False): 0.51710224667583682,
#  (21, 9, False): 0.55138121546961338,
#  (8, 3, False): -0.38900578733696123,
#  (13, 10, False): -0.58947166623185177,
#  (16, 4, True): -0.22184004007346805,
#  (19, 4, True): 0.27260599208592429,
#  (8, 7, False): -0.37796970502258842,
#  (13, 10, True): -0.35518629619317299,
#  (16, 10, True): -0.41355892466395749,
#  (18, 8, True): -0.17794812233836627,
#  (19, 8, True): 0.42961306630371388,
#  (9, 6, False): -0.1112737056237286,
#  (15, 9, False): -0.5929190913194663,
#  (20, 7, False): 0.43972711965134714,
#  (15, 1, False): -0.71211337672768249,
#  (10, 9, False): -0.19497410684772243,
#  (6, 3, False): -0.36840747904577698,
#  (11, 6, False): -0.01379106244451021,
#  (13, 8, True): -0.2720812557710065,
#  (16, 8, True): -0.34648675333223633,
#  (11, 1, False): -0.39623772958681408,
#  (7, 4, False): -0.34777479892761398,
#  (7, 9, False): -0.46504267130665344,
#  (21, 7, True): 0.72425065599805516,
#  (17, 4, True): -0.23925477523402061,
#  (5, 10, False): -0.55362516271607187,
#  (21, 6, True): 0.69518140589569166,
#  (18, 8, False): -0.52920641368741828,
#  (14, 10, True): -0.37587744066529327,
#  (13, 4, False): -0.43395915108071559,
#  (21, 2, True): 0.68031649301881048,
#  (17, 8, False): -0.59568824261916919,
#  (8, 8, False): -0.42224644451365101,
#  (13, 4, True): -0.11790504577389825,
#  (21, 9, True): 0.71240083658802711,
#  (4, 2, False): -0.42364928909952609,
#  (5, 6, False): -0.32342148861753695,
#  (6, 4, False): -0.36247465712581994,
#  (21, 3, True): 0.6943107984149357,
#  (17, 8, True): -0.31923236136638355,
#  (18, 9, True): -0.33611309438811943,
#  (9, 4, False): -0.20028498147620405,
#  (8, 10, False): -0.54536104076914071,
#  (14, 4, False): -0.45563226582334865,
#  (5, 5, False): -0.28128742077747598,
#  (9, 7, False): -0.20986657730448921,
#  (6, 8, False): -0.49680549296148035,
#  (15, 2, True): -0.21604868506846336,
#  (18, 7, True): -0.047851690294438393,
#  (16, 5, True): -0.21961379031442727,
#  (9, 8, False): -0.22945491914796939,
#  (14, 3, True): -0.15916892502258356,
#  (16, 2, False): -0.56860723504978816,
#  (21, 6, False): 0.51928571428571435,
#  (7, 5, False): -0.33863627431715471,
#  (11, 5, False): -0.072834705148363058,
#  (8, 4, False): -0.36050725893073698,
#  (10, 4, False): -0.089383207321925978,
#  (18, 4, True): -0.1551833607006021,
#  (14, 7, True): -0.20971638304971638,
#  (18, 2, True): -0.1931194553331958,
#  (14, 2, True): -0.19713033080908732,
#  (17, 2, True): -0.27397048960429243,
#  (18, 5, True): -0.19487226655016215,
#  (12, 9, False): -0.50885792913656691,
#  (4, 6, False): -0.20311111111111113,
#  (10, 1, False): -0.4606284220431241,
#  (18, 1, True): -0.43688988903546216,
#  (11, 4, False): -0.11623082715036252,
#  (8, 1, False): -0.6457415665316405,
#  (15, 6, False): -0.48565415795645744,
#  (21, 5, False): 0.50894308943089439,
#  (12, 10, True): -0.31070411070411069,
#  (7, 1, False): -0.6613139896373057,
#  (5, 3, False): -0.35116559858827906,
#  (6, 9, False): -0.4699023236061397,
#  (6, 6, False): -0.25748855461085679,
#  (12, 7, True): -0.27625243981782693,
#  (15, 1, True): -0.52453137734311328,
#  (7, 3, False): -0.38736111111111116,
#  (14, 5, True): -0.097273049226773697,
#  (15, 4, True): -0.12595918367346939,
#  (9, 5, False): -0.16652286453839518,
#  (17, 5, True): -0.12572647294054917,
#  (7, 6, False): -0.31069401044361206,
#  (6, 2, False): -0.36686159844054589,
#  (17, 7, True): -0.22833548228648617,
#  (4, 1, False): -0.67147952281392198,
#  (6, 5, False): -0.40341075198960535,
#  (20, 6, True): 0.50753387533875349,
#  (13, 1, True): -0.52093338760005437,
#  (5, 1, False): -0.67655367231638419,
#  (13, 3, True): -0.18728070175438599,
#  (5, 4, False): -0.33422531094729324,
#  (8, 6, False): -0.36014319404149919,
#  (14, 8, True): -0.21911990602692691,
#  (8, 2, False): -0.37345872518286316,
#  (14, 4, True): -0.20154128440366975,
#  (4, 8, False): -0.36641711229946528,
#  (15, 3, True): -0.25295055821371609,
#  (18, 3, True): -0.20731520908396117,
#  (5, 8, False): -0.49997290380852027,
#  (16, 7, True): -0.26639175257731962,
#  (12, 3, True): -0.077828054298642535,
#  (14, 6, True): -0.13670464268023597,
#  (17, 3, True): -0.13767218696796163,
#  (15, 9, True): -0.33018963436003274,
#  (20, 9, True): 0.56844384508727619,
#  (19, 9, True): 0.21453129494015355,
#  (16, 3, True): -0.24092803030303031,
#  (16, 2, True): -0.29467781603541565,
#  (7, 2, False): -0.36022363472994112,
#  (14, 1, True): -0.51439460568748174,
#  (20, 5, True): 0.50157105030891447,
#  (12, 5, True): -0.12682124158563951,
#  (20, 3, True): 0.47947574547287608,
#  (5, 2, False): -0.38104361787530105,
#  (17, 9, True): -0.33693551774837222,
#  (19, 6, True): 0.47048501577287072,
#  (12, 8, True): -0.19353535353535353,
#  (12, 4, True): 0.0099917714823086895,
#  (19, 3, True): 0.32758764607679469,
#  (15, 7, True): -0.24573196331897029,
#  (12, 9, True): -0.27340994424849246,
#  (13, 6, True): -0.068459383753501413,
#  (19, 2, True): 0.2554865758284286,
#  (15, 8, True): -0.25513502241684916,
#  (15, 6, True): -0.11679500055797344,
#  (5, 7, False): -0.39735334781749954,
#  (4, 4, False): -0.31829828378051728,
#  (13, 2, True): -0.16255516328331862,
#  (12, 2, True): -0.094516848655629912,
#  (4, 5, False): -0.35217391304347828,
#  (6, 1, False): -0.63911045218680507,
#  (12, 1, True): -0.54343048256091742,
#  (5, 9, False): -0.46706091070372563,
#  (14, 9, True): -0.30017516640808772,
#  (4, 9, False): -0.53083003952569174}

# %%
len(V_to_plot.keys()), len(Q.keys())
# Out:
# (280, 280)

# %%
for key in N.keys():
    print(f"key {key} value {N[key]}")
# Out:
# key (16, 5, False) value [  871.  3583.]
# key (18, 5, False) value [  884.  3608.]
# key (14, 10, False) value [  3641.  14204.]
# key (19, 10, True) value [ 2383.   605.]
# key (20, 10, True) value [ 2481.   681.]
# key (7, 8, False) value [ 167.  739.]
# key (13, 5, False) value [  866.  3383.]
# key (17, 5, False) value [  898.  3696.]
# key (8, 5, False) value [ 238.  935.]
# key (13, 2, False) value [  815.  3482.]
# key (19, 2, False) value [ 3517.   905.]
# key (18, 10, True) value [  532.  2224.]
# key (13, 1, False) value [  888.  3395.]
# key (17, 9, False) value [  900.  3656.]
# key (12, 3, False) value [  830.  3487.]
# key (9, 10, False) value [ 1223.  4776.]
# key (19, 10, False) value [ 14245.   3500.]
# key (20, 10, False) value [ 20052.   5015.]
# key (15, 10, True) value [  439.  1801.]
# key (16, 6, True) value [ 121.  467.]
# key (18, 6, True) value [ 139.  556.]
# key (18, 6, False) value [  875.  3643.]
# key (10, 5, False) value [  320.  1416.]
# key (17, 4, False) value [  878.  3617.]
# key (10, 10, False) value [ 1460.  5783.]
# key (14, 5, False) value [  870.  3549.]
# key (14, 1, False) value [  929.  3565.]
# key (15, 2, False) value [  895.  3543.]
# key (15, 4, False) value [  889.  3635.]
# key (14, 2, False) value [  909.  3545.]
# key (20, 8, True) value [ 600.  153.]
# key (12, 10, False) value [  3457.  13800.]
# key (17, 10, False) value [  3661.  14541.]
# key (4, 7, False) value [  46.  199.]
# key (19, 1, False) value [ 3688.   896.]
# key (20, 7, True) value [ 656.  152.]
# key (19, 7, False) value [ 3489.   853.]
# key (20, 2, False) value [ 5021.  1270.]
# key (8, 9, False) value [ 229.  948.]
# key (12, 6, False) value [  837.  3407.]
# key (16, 6, False) value [  910.  3524.]
# key (10, 3, False) value [  356.  1414.]
# key (12, 2, False) value [  903.  3451.]
# key (17, 2, False) value [  931.  3664.]
# key (18, 7, False) value [  947.  3586.]
# key (18, 10, False) value [  3629.  14612.]
# key (20, 4, False) value [ 5028.  1256.]
# key (11, 10, False) value [ 1795.  6796.]
# key (20, 5, False) value [ 5005.  1226.]
# key (17, 3, False) value [  923.  3599.]
# key (21, 10, True) value [ 7116.  1792.]
# key (17, 1, False) value [  909.  3571.]
# key (13, 7, False) value [  869.  3524.]
# key (21, 7, False) value [ 2195.   567.]
# key (21, 10, False) value [ 8858.  2191.]
# key (21, 1, True) value [ 1732.   423.]
# key (10, 8, False) value [  364.  1432.]
# key (17, 1, True) value [ 133.  514.]
# key (11, 8, False) value [  457.  1751.]
# key (21, 8, False) value [ 2236.   576.]
# key (18, 4, False) value [  881.  3656.]
# key (13, 6, False) value [  885.  3554.]
# key (17, 6, False) value [  959.  3557.]
# key (16, 10, False) value [  3613.  14350.]
# key (16, 1, False) value [  895.  3598.]
# key (16, 8, False) value [  913.  3557.]
# key (20, 8, False) value [ 4955.  1227.]
# key (9, 9, False) value [  315.  1133.]
# key (16, 9, False) value [  937.  3604.]
# key (20, 3, False) value [ 5116.  1269.]
# key (12, 1, False) value [  826.  3522.]
# key (17, 10, True) value [  541.  2065.]
# key (11, 7, False) value [  437.  1811.]
# key (21, 1, False) value [ 2200.   581.]
# key (15, 3, False) value [  875.  3563.]
# key (13, 9, False) value [  869.  3520.]
# key (14, 9, False) value [  937.  3531.]
# key (4, 3, False) value [  47.  154.]
# key (16, 3, False) value [  877.  3568.]
# key (14, 8, False) value [  856.  3462.]
# key (15, 10, False) value [  3585.  14312.]
# key (13, 8, False) value [  877.  3390.]
# key (9, 3, False) value [  305.  1223.]
# key (19, 3, False) value [ 3596.   898.]
# key (12, 4, False) value [  906.  3415.]
# key (21, 4, False) value [ 2233.   541.]
# key (10, 2, False) value [  343.  1432.]
# key (13, 7, True) value [  78.  378.]
# key (19, 7, True) value [ 641.  162.]
# key (17, 7, False) value [  942.  3590.]
# key (18, 3, False) value [  898.  3608.]
# key (12, 5, False) value [  860.  3442.]
# key (19, 6, False) value [ 3620.   881.]
# key (19, 9, False) value [ 3540.   856.]
# key (12, 8, False) value [  820.  3444.]
# key (21, 5, True) value [ 1792.   432.]
# key (19, 8, False) value [ 3416.   882.]
# key (20, 6, False) value [ 5146.  1231.]
# key (13, 5, True) value [  93.  401.]
# key (15, 5, True) value [ 102.  460.]
# key (15, 5, False) value [  869.  3505.]
# key (19, 5, False) value [ 3490.   909.]
# key (9, 2, False) value [  311.  1134.]
# key (20, 2, True) value [ 608.  170.]
# key (11, 2, False) value [  419.  1670.]
# key (21, 2, False) value [ 2238.   579.]
# key (18, 2, False) value [  898.  3682.]
# key (19, 1, True) value [ 620.  166.]
# key (10, 7, False) value [  371.  1449.]
# key (12, 7, False) value [  861.  3508.]
# key (10, 6, False) value [  340.  1461.]
# key (12, 6, True) value [  33.  191.]
# key (17, 6, True) value [ 136.  518.]
# key (21, 8, True) value [ 1656.   412.]
# key (15, 8, False) value [  865.  3626.]
# key (16, 1, True) value [ 107.  478.]
# key (20, 1, True) value [ 640.  142.]
# key (9, 1, False) value [  276.  1240.]
# key (4, 10, False) value [ 153.  749.]
# key (14, 6, False) value [  864.  3553.]
# key (13, 9, True) value [  94.  421.]
# key (16, 9, True) value [ 106.  470.]
# key (18, 9, False) value [  923.  3589.]
# key (6, 10, False) value [  565.  2186.]
# key (7, 7, False) value [ 212.  756.]
# key (11, 9, False) value [  445.  1705.]
# key (18, 1, False) value [  894.  3663.]
# key (20, 9, False) value [ 5018.  1221.]
# key (14, 7, False) value [  885.  3448.]
# key (15, 7, False) value [  873.  3596.]
# key (6, 7, False) value [ 132.  570.]
# key (16, 7, False) value [  903.  3606.]
# key (19, 5, True) value [ 597.  146.]
# key (14, 3, False) value [  888.  3536.]
# key (16, 4, False) value [  905.  3521.]
# key (7, 10, False) value [  796.  3151.]
# key (20, 1, False) value [ 4987.  1261.]
# key (21, 4, True) value [ 1784.   381.]
# key (11, 3, False) value [  439.  1776.]
# key (20, 4, True) value [ 618.  169.]
# key (19, 4, False) value [ 3594.   889.]
# key (13, 3, False) value [  820.  3535.]
# key (21, 3, False) value [ 2181.   565.]
# key (21, 9, False) value [ 2172.   576.]
# key (8, 3, False) value [ 255.  908.]
# key (13, 10, False) value [  3517.  13826.]
# key (16, 4, True) value [ 113.  477.]
# key (19, 4, True) value [ 610.  145.]
# key (8, 7, False) value [ 212.  994.]
# key (13, 10, True) value [  383.  1491.]
# key (16, 10, True) value [  448.  1828.]
# key (18, 8, True) value [ 135.  574.]
# key (19, 8, True) value [ 556.  148.]
# key (9, 6, False) value [  311.  1176.]
# key (15, 9, False) value [  914.  3558.]
# key (20, 7, False) value [ 5120.  1262.]
# key (15, 1, False) value [  920.  3627.]
# key (10, 9, False) value [  337.  1562.]
# key (6, 3, False) value [ 141.  594.]
# key (11, 6, False) value [  403.  1744.]
# key (13, 8, True) value [  75.  361.]
# key (16, 8, True) value [ 103.  472.]
# key (11, 1, False) value [  420.  1693.]
# key (7, 4, False) value [ 175.  746.]
# key (7, 9, False) value [ 162.  745.]
# key (21, 7, True) value [ 1697.   446.]
# key (17, 4, True) value [ 127.  519.]
# key (5, 10, False) value [  363.  1456.]
# key (21, 6, True) value [ 1764.   424.]
# key (18, 8, False) value [  919.  3659.]
# key (14, 10, True) value [  394.  1609.]
# key (13, 4, False) value [  878.  3446.]
# key (21, 2, True) value [ 1743.   431.]
# key (17, 8, False) value [  911.  3645.]
# key (8, 8, False) value [  228.  1014.]
# key (13, 4, True) value [  77.  366.]
# key (21, 9, True) value [ 1742.   443.]
# key (4, 2, False) value [  40.  211.]
# key (5, 6, False) value [  86.  379.]
# key (6, 4, False) value [ 120.  559.]
# key (21, 3, True) value [ 1723.   441.]
# key (17, 8, True) value [ 123.  491.]
# key (18, 9, True) value [ 149.  564.]
# key (9, 4, False) value [  290.  1210.]
# key (8, 10, False) value [ 1022.  3857.]
# key (14, 4, False) value [  942.  3432.]
# key (5, 5, False) value [ 101.  339.]
# key (9, 7, False) value [  321.  1255.]
# key (6, 8, False) value [ 134.  563.]
# key (15, 2, True) value [ 107.  430.]
# key (18, 7, True) value [ 131.  560.]
# key (16, 5, True) value [ 126.  471.]
# key (9, 8, False) value [  307.  1233.]
# key (14, 3, True) value [ 108.  410.]
# key (16, 2, False) value [  867.  3583.]
# key (21, 6, False) value [ 2240.   536.]
# key (7, 5, False) value [ 210.  727.]
# key (11, 5, False) value [  422.  1694.]
# key (8, 4, False) value [ 248.  931.]
# key (10, 4, False) value [  359.  1400.]
# key (18, 4, True) value [ 145.  567.]
# key (14, 7, True) value [ 111.  405.]
# key (18, 2, True) value [ 148.  524.]
# key (14, 2, True) value [ 104.  386.]
# key (17, 2, True) value [ 120.  497.]
# key (18, 5, True) value [ 157.  554.]
# key (12, 9, False) value [  816.  3420.]
# key (4, 6, False) value [  45.  200.]
# key (10, 1, False) value [  337.  1479.]
# key (18, 1, True) value [ 147.  526.]
# key (11, 4, False) value [  409.  1734.]
# key (8, 1, False) value [  232.  1013.]
# key (15, 6, False) value [  880.  3566.]
# key (21, 5, False) value [ 2214.   588.]
# key (12, 10, True) value [ 189.  728.]
# key (7, 1, False) value [ 193.  750.]
# key (5, 3, False) value [  97.  333.]
# key (6, 9, False) value [ 159.  622.]
# key (6, 6, False) value [ 139.  528.]
# key (12, 7, True) value [  53.  174.]
# key (15, 1, True) value [ 120.  409.]
# key (7, 3, False) value [ 180.  768.]
# key (14, 5, True) value [  86.  394.]
# key (15, 4, True) value [ 100.  441.]
# key (9, 5, False) value [  305.  1140.]
# key (17, 5, True) value [ 121.  496.]
# key (7, 6, False) value [ 191.  759.]
# key (6, 2, False) value [ 152.  540.]
# key (17, 7, True) value [ 122.  534.]
# key (4, 1, False) value [  47.  173.]
# key (6, 5, False) value [ 141.  524.]
# key (20, 6, True) value [ 615.  135.]
# key (13, 1, True) value [  81.  364.]
# key (5, 1, False) value [ 104.  354.]
# key (13, 3, True) value [ 114.  384.]
# key (5, 4, False) value [  83.  371.]
# key (8, 6, False) value [ 236.  999.]
# key (14, 8, True) value [  93.  357.]
# key (8, 2, False) value [ 237.  957.]
# key (14, 4, True) value [ 109.  400.]
# key (4, 8, False) value [  55.  170.]
# key (15, 3, True) value [ 114.  429.]
# key (18, 3, True) value [ 129.  568.]
# key (5, 8, False) value [  91.  365.]
# key (16, 7, True) value [ 100.  485.]
# key (12, 3, True) value [  52.  204.]
# key (14, 6, True) value [ 106.  419.]
# key (17, 3, True) value [ 142.  546.]
# key (15, 9, True) value [ 122.  421.]
# key (20, 9, True) value [ 646.  163.]
# key (19, 9, True) value [ 587.  154.]
# key (16, 3, True) value [ 128.  495.]
# key (16, 2, True) value [ 107.  475.]
# key (7, 2, False) value [ 199.  755.]
# key (14, 1, True) value [ 126.  379.]
# key (20, 5, True) value [ 618.  165.]
# key (12, 5, True) value [  35.  191.]
# key (20, 3, True) value [ 629.  164.]
# key (5, 2, False) value [ 101.  370.]
# key (17, 9, True) value [ 108.  529.]
# key (19, 6, True) value [ 634.  160.]
# key (12, 8, True) value [  45.  154.]
# key (12, 4, True) value [  47.  181.]
# key (19, 3, True) value [ 599.  144.]
# key (15, 7, True) value [ 105.  431.]
# key (12, 9, True) value [  47.  187.]
# key (13, 6, True) value [  85.  357.]
# key (19, 2, True) value [ 632.  157.]
# key (15, 8, True) value [  92.  417.]
# key (15, 6, True) value [ 103.  435.]
# key (5, 7, False) value [  83.  366.]
# key (4, 4, False) value [  42.  197.]
# key (13, 2, True) value [ 103.  352.]
# key (12, 2, True) value [  51.  167.]
# key (4, 5, False) value [  44.  184.]
# key (6, 1, False) value [ 142.  570.]
# key (12, 1, True) value [  46.  182.]
# key (5, 9, False) value [  76.  356.]
# key (14, 9, True) value [ 106.  377.]
# key (4, 9, False) value [  44.  184.]

# %%
for key in returns_sum.keys():
    print(f"key {key} value {returns_sum[key]}")
# Out:
# key (16, 5, False) value [ -133. -2202.]
# key (18, 5, False) value [  169. -2521.]
# key (14, 10, False) value [-2133. -8854.]
# key (19, 10, True) value [-118. -185.]
# key (20, 10, True) value [ 1101.  -186.]
# key (7, 8, False) value [ -81. -314.]
# key (13, 5, False) value [ -136. -1646.]
# key (17, 5, False) value [  -18. -2371.]
# key (8, 5, False) value [ -30. -342.]
# key (13, 2, False) value [ -235. -1804.]
# key (19, 2, False) value [ 1405.  -707.]
# key (18, 10, True) value [-119. -842.]
# key (13, 1, False) value [ -688. -2266.]
# key (17, 9, False) value [ -409. -2388.]
# key (12, 3, False) value [ -202. -1641.]
# key (9, 10, False) value [ -689. -1973.]
# key (19, 10, False) value [ -479. -2825.]
# key (20, 10, False) value [ 8626. -4444.]
# key (15, 10, True) value [-243. -585.]
# key (16, 6, True) value [-13. -39.]
# key (18, 6, True) value [  38. -132.]
# key (18, 6, False) value [  245. -2414.]
# key (10, 5, False) value [-68. -37.]
# key (17, 4, False) value [  -91. -2344.]
# key (10, 10, False) value [ -858. -1383.]
# key (14, 5, False) value [ -152. -1781.]
# key (14, 1, False) value [ -689. -2413.]
# key (15, 2, False) value [ -251. -2140.]
# key (15, 4, False) value [ -179. -2106.]
# key (14, 2, False) value [ -291. -1929.]
# key (20, 8, True) value [ 485.  -14.]
# key (12, 10, False) value [-1985. -7530.]
# key (17, 10, False) value [ -1671. -10139.]
# key (4, 7, False) value [-16. -79.]
# key (19, 1, False) value [-451. -714.]
# key (20, 7, True) value [ 512.  -12.]
# key (19, 7, False) value [ 2185.  -651.]
# key (20, 2, False) value [ 3229. -1103.]
# key (8, 9, False) value [-123. -443.]
# key (12, 6, False) value [  -91. -1506.]
# key (16, 6, False) value [ -146. -2121.]
# key (10, 3, False) value [-92. -94.]
# key (12, 2, False) value [ -293. -1601.]
# key (17, 2, False) value [ -146. -2442.]
# key (18, 7, False) value [  366. -2457.]
# key (18, 10, False) value [  -808. -10644.]
# key (20, 4, False) value [ 3277. -1117.]
# key (11, 10, False) value [-1013. -1155.]
# key (20, 5, False) value [ 3308. -1108.]
# key (17, 3, False) value [ -127. -2319.]
# key (21, 10, True) value [ 6310.  -345.]
# key (17, 1, False) value [ -553. -2699.]
# key (13, 7, False) value [ -409. -1728.]
# key (21, 7, False) value [ 2038.  -567.]
# key (21, 10, False) value [ 7822. -2191.]
# key (21, 1, True) value [ 1099.  -107.]
# key (10, 8, False) value [-194.  -24.]
# key (17, 1, True) value [ -76. -246.]
# key (11, 8, False) value [-233. -124.]
# key (21, 8, False) value [ 2081.  -576.]
# key (18, 4, False) value [  144. -2580.]
# key (13, 6, False) value [  -97. -1674.]
# key (17, 6, False) value [    4. -2251.]
# key (16, 10, False) value [-2043. -9675.]
# key (16, 1, False) value [ -661. -2575.]
# key (16, 8, False) value [ -463. -2115.]
# key (20, 8, False) value [ 3908. -1089.]
# key (9, 9, False) value [-163. -266.]
# key (16, 9, False) value [ -529. -2323.]
# key (20, 3, False) value [ 3327. -1127.]
# key (12, 1, False) value [ -648. -2225.]
# key (17, 10, True) value [-258. -799.]
# key (11, 7, False) value [-201.  -57.]
# key (21, 1, False) value [ 1384.  -581.]
# key (15, 3, False) value [ -223. -2138.]
# key (13, 9, False) value [ -483. -1794.]
# key (14, 9, False) value [ -515. -1966.]
# key (4, 3, False) value [-17. -59.]
# key (16, 3, False) value [ -245. -2188.]
# key (14, 8, False) value [ -430. -1790.]
# key (15, 10, False) value [-2173. -9205.]
# key (13, 8, False) value [ -425. -1664.]
# key (9, 3, False) value [ -49. -257.]
# key (19, 3, False) value [ 1403.  -689.]
# key (12, 4, False) value [ -142. -1561.]
# key (21, 4, False) value [ 1997.  -541.]
# key (10, 2, False) value [-131. -116.]
# key (13, 7, True) value [-38. -63.]
# key (19, 7, True) value [ 414.   14.]
# key (17, 7, False) value [  -67. -2231.]
# key (18, 3, False) value [  151. -2511.]
# key (12, 5, False) value [ -156. -1525.]
# key (19, 6, False) value [ 1845.  -669.]
# key (19, 9, False) value [ 991. -633.]
# key (12, 8, False) value [ -448. -1636.]
# key (21, 5, True) value [ 1610.   -51.]
# key (19, 8, False) value [ 2066.  -693.]
# key (20, 6, False) value [ 3636. -1091.]
# key (13, 5, True) value [-21. -58.]
# key (15, 5, True) value [ 10. -92.]
# key (15, 5, False) value [ -245. -2069.]
# key (19, 5, False) value [ 1603.  -689.]
# key (9, 2, False) value [ -93. -247.]
# key (20, 2, True) value [ 403.  -14.]
# key (11, 2, False) value [-133. -196.]
# key (21, 2, False) value [ 1982.  -579.]
# key (18, 2, False) value [  122. -2595.]
# key (19, 1, True) value [-62. -68.]
# key (10, 7, False) value [-151.  -80.]
# key (12, 7, False) value [ -359. -1574.]
# key (10, 6, False) value [ -46. -118.]
# key (12, 6, True) value [ 7.  0.]
# key (17, 6, True) value [   5. -108.]
# key (21, 8, True) value [ 1544.   -30.]
# key (15, 8, False) value [ -439. -2067.]
# key (16, 1, True) value [ -89. -223.]
# key (20, 1, True) value [ 108.  -28.]
# key (9, 1, False) value [-218. -617.]
# key (4, 10, False) value [ -89. -392.]
# key (14, 6, False) value [ -116. -1858.]
# key (13, 9, True) value [-50. -69.]
# key (16, 9, True) value [ -52. -132.]
# key (18, 9, False) value [  -62. -2532.]
# key (6, 10, False) value [ -327. -1213.]
# key (7, 7, False) value [ -86. -307.]
# key (11, 9, False) value [-251. -144.]
# key (18, 1, False) value [ -311. -2811.]
# key (20, 9, False) value [ 3847. -1091.]
# key (14, 7, False) value [ -443. -1724.]
# key (15, 7, False) value [ -409. -1948.]
# key (6, 7, False) value [ -62. -228.]
# key (16, 7, False) value [ -461. -2198.]
# key (19, 5, True) value [ 255.   -1.]
# key (14, 3, False) value [ -202. -1879.]
# key (16, 4, False) value [ -225. -2136.]
# key (7, 10, False) value [ -420. -1738.]
# key (20, 1, False) value [  790. -1135.]
# key (21, 4, True) value [ 1578.     2.]
# key (11, 3, False) value [ -85. -121.]
# key (20, 4, True) value [ 383.  -18.]
# key (19, 4, False) value [ 1570.  -703.]
# key (13, 3, False) value [ -242. -1777.]
# key (21, 3, False) value [ 1955.  -565.]
# key (21, 9, False) value [ 2040.  -576.]
# key (8, 3, False) value [ -59. -389.]
# key (13, 10, False) value [-2003. -8219.]
# key (16, 4, True) value [ -23. -108.]
# key (19, 4, True) value [ 231.  -22.]
# key (8, 7, False) value [-114. -336.]
# key (13, 10, True) value [-225. -443.]
# key (16, 10, True) value [-248. -692.]
# key (18, 8, True) value [  21. -150.]
# key (19, 8, True) value [ 323.  -26.]
# key (9, 6, False) value [-81. -87.]
# key (15, 9, False) value [ -522. -2129.]
# key (20, 7, False) value [ 3934. -1104.]
# key (15, 1, False) value [ -726. -2513.]
# key (10, 9, False) value [-187. -164.]
# key (6, 3, False) value [ -29. -243.]
# key (11, 6, False) value [-13. -16.]
# key (13, 8, True) value [-53. -59.]
# key (16, 8, True) value [ -51. -146.]
# key (11, 1, False) value [-328. -508.]
# key (7, 4, False) value [ -35. -287.]
# key (7, 9, False) value [ -94. -325.]
# key (21, 7, True) value [ 1562.   -27.]
# key (17, 4, True) value [ -10. -145.]
# key (5, 10, False) value [-217. -790.]
# key (21, 6, True) value [ 1588.   -53.]
# key (18, 8, False) value [   99. -2519.]
# key (14, 10, True) value [-238. -513.]
# key (13, 4, False) value [ -198. -1675.]
# key (21, 2, True) value [ 1552.   -69.]
# key (17, 8, False) value [ -381. -2333.]
# key (8, 8, False) value [-118. -404.]
# key (13, 4, True) value [ -5. -48.]
# key (21, 9, True) value [ 1624.   -74.]
# key (4, 2, False) value [-18. -88.]
# key (5, 6, False) value [ -12. -140.]
# key (6, 4, False) value [ -26. -223.]
# key (21, 3, True) value [ 1511.   -16.]
# key (17, 8, True) value [ -35. -161.]
# key (18, 9, True) value [ -38. -201.]
# key (9, 4, False) value [ -68. -232.]
# key (8, 10, False) value [ -596. -2067.]
# key (14, 4, False) value [ -172. -1798.]
# key (5, 5, False) value [  -5. -115.]
# key (9, 7, False) value [-167. -166.]
# key (6, 8, False) value [ -72. -274.]
# key (15, 2, True) value [-27. -89.]
# key (18, 7, True) value [ 51. -88.]
# key (16, 5, True) value [ -26. -105.]
# key (9, 8, False) value [-159. -194.]
# key (14, 3, True) value [-28. -55.]
# key (16, 2, False) value [ -291. -2246.]
# key (21, 6, False) value [ 2014.  -536.]
# key (7, 5, False) value [ -54. -261.]
# key (11, 5, False) value [-64. -90.]
# key (8, 4, False) value [ -40. -382.]
# key (10, 4, False) value [-63. -95.]
# key (18, 4, True) value [  44. -153.]
# key (14, 7, True) value [-55. -56.]
# key (18, 2, True) value [  13. -138.]
# key (14, 2, True) value [-40. -58.]
# key (17, 2, True) value [ -34. -135.]
# key (18, 5, True) value [  42. -172.]
# key (12, 9, False) value [ -468. -1685.]
# key (4, 6, False) value [ -7. -43.]
# key (10, 1, False) value [-253. -574.]
# key (18, 1, True) value [ -45. -247.]
# key (11, 4, False) value [ -99. -147.]
# key (8, 1, False) value [-182. -619.]
# key (15, 6, False) value [ -138. -2025.]
# key (21, 5, False) value [ 1962.  -588.]
# key (12, 10, True) value [-115. -172.]
# key (7, 1, False) value [-141. -483.]
# key (5, 3, False) value [ -27. -123.]
# key (6, 9, False) value [ -75. -292.]
# key (6, 6, False) value [ -21. -150.]
# key (12, 7, True) value [-33. -33.]
# key (15, 1, True) value [ -80. -200.]
# key (7, 3, False) value [ -58. -310.]
# key (14, 5, True) value [-20. -25.]
# key (15, 4, True) value [-14. -54.]
# key (9, 5, False) value [ -87. -156.]
# key (17, 5, True) value [  2. -80.]
# key (7, 6, False) value [ -35. -260.]
# key (6, 2, False) value [ -48. -205.]
# key (17, 7, True) value [ -15. -136.]
# key (4, 1, False) value [ -35. -113.]
# key (6, 5, False) value [ -39. -228.]
# key (20, 6, True) value [ 397.   -6.]
# key (13, 1, True) value [ -65. -164.]
# key (5, 1, False) value [ -78. -233.]
# key (13, 3, True) value [-26. -68.]
# key (5, 4, False) value [ -17. -136.]
# key (8, 6, False) value [ -64. -382.]
# key (14, 8, True) value [-55. -45.]
# key (8, 2, False) value [ -79. -367.]
# key (14, 4, True) value [-27. -76.]
# key (4, 8, False) value [-27. -57.]
# key (15, 3, True) value [  -6. -130.]
# key (18, 3, True) value [   8. -156.]
# key (5, 8, False) value [ -41. -187.]
# key (16, 7, True) value [ -40. -113.]
# key (12, 3, True) value [ -8. -12.]
# key (14, 6, True) value [-34. -38.]
# key (17, 3, True) value [ -1. -93.]
# key (15, 9, True) value [ -60. -122.]
# key (20, 9, True) value [ 461.   -2.]
# key (19, 9, True) value [ 186.  -30.]
# key (16, 3, True) value [-58. -93.]
# key (16, 2, True) value [ -27. -145.]
# key (7, 2, False) value [ -59. -284.]
# key (14, 1, True) value [ -98. -170.]
# key (20, 5, True) value [ 409.  -23.]
# key (12, 5, True) value [ -9. -18.]
# key (20, 3, True) value [ 400.  -24.]
# key (5, 2, False) value [ -21. -157.]
# key (17, 9, True) value [ -57. -153.]
# key (19, 6, True) value [ 358.   15.]
# key (12, 8, True) value [-19. -21.]
# key (12, 4, True) value [-7.  9.]
# key (19, 3, True) value [ 264.  -18.]
# key (15, 7, True) value [-53. -78.]
# key (12, 9, True) value [-17. -47.]
# key (13, 6, True) value [-11. -19.]
# key (19, 2, True) value [ 228.  -26.]
# key (15, 8, True) value [-60. -65.]
# key (15, 6, True) value [-27. -35.]
# key (5, 7, False) value [ -37. -141.]
# key (4, 4, False) value [ -8. -69.]
# key (13, 2, True) value [-17. -57.]
# key (12, 2, True) value [ -7. -14.]
# key (4, 5, False) value [  0. -81.]
# key (6, 1, False) value [-104. -351.]
# key (12, 1, True) value [-34. -90.]
# key (5, 9, False) value [ -40. -161.]
# key (14, 9, True) value [-50. -97.]
# key (4, 9, False) value [-24. -97.]

# %% [markdown]
# ### Part 2: MC Control
#
# In this section, you will write your own implementation of constant-$\alpha$ MC control.
#
# Your algorithm has four arguments:
# - `env`: This is an instance of an OpenAI Gym environment.
# - `num_episodes`: This is the number of episodes that are generated through agent-environment interaction.
# - `alpha`: This is the step-size parameter for the update step.
# - `gamma`: This is the discount rate.  It must be a value between 0 and 1, inclusive (default value: `1`).
#
# The algorithm returns as output:
# - `Q`: This is a dictionary (of one-dimensional arrays) where `Q[s][a]` is the estimated action value corresponding to state `s` and action `a`.
# - `policy`: This is a dictionary where `policy[s]` returns the action that the agent chooses after observing state `s`.
#
# (_Feel free to define additional functions to help you to organize your code._)

# %%
def generate_episode_from_Q(env, Q, epsilon, nA):
    """ generates an episode from following the epsilon-greedy policy """
    episode = []
    state = env.reset()
    while True:
        action = np.random.choice(np.arange(nA), p=get_probs(Q[state], epsilon, nA)) \
                                    if state in Q else env.action_space.sample()
        next_state, reward, done, info = env.step(action)
        episode.append((state, action, reward))
        state = next_state
        if done:
            break
    return episode

def get_probs(Q_s, epsilon, nA):
    """ obtains the action probabilities corresponding to epsilon-greedy policy 
        overwrite the current returned on the state
    """
    policy_s = np.ones(nA) * epsilon / nA
    best_a = np.argmax(Q_s)
    policy_s[best_a] = 1 - epsilon + (epsilon / nA)
    return policy_s

def update_Q(env, episode, Q, alpha, gamma):
    """ updates the action-value function estimate using the most recent episode """
    states, actions, rewards = zip(*episode)
    # prepare for discounting
    discounts = np.array([gamma**i for i in range(len(rewards)+1)])
    for i, state in enumerate(states):
        old_Q = Q[state][actions[i]] 
        # Constant-alpha
        Q[state][actions[i]] = old_Q + alpha*(sum(rewards[i:]*discounts[:-(1+i)]) - old_Q)
    return Q

# %%
def mc_control(env, num_episodes, alpha, gamma=1.0, eps_start=1.0, eps_decay=.99999, eps_min=0.05):
    nA = env.action_space.n
    # initialize empty dictionary of arrays
    Q = defaultdict(lambda: np.zeros(nA))
    epsilon = eps_start
    # loop over episodes
    for i_episode in range(1, num_episodes+1):
        # monitor progress
        if i_episode % 1000 == 0:
            print("\rEpisode {}/{}.".format(i_episode, num_episodes), end="")
            sys.stdout.flush()
        # set the value of epsilon
        epsilon = max(epsilon*eps_decay, eps_min)
        # generate an episode by following epsilon-greedy policy
        episode = generate_episode_from_Q(env, Q, epsilon, nA)
        # update the action-value function estimate using the episode ##### Incremental Mean ###
        Q = update_Q(env, episode, Q, alpha, gamma)
    # determine the policy corresponding to the final action-value function estimate
    policy = dict((k,np.argmax(v)) for k, v in Q.items())
    return policy, Q

# %% [markdown]
# Use the cell below to obtain the estimated optimal policy and action-value function.  Note that you should fill in your own values for the `num_episodes` and `alpha` parameters.

# %% [markdown]
# ### Alpha 0.03

# %%
# obtain the estimated optimal policy and action-value function
policy, Q = mc_control(env, 500000, 0.03)
# Out:
# Episode 500000/500000.

# %% [markdown]
# Next, we plot the corresponding state-value function.

# %%
# obtain the corresponding state-value function
V = dict((k,np.max(v)) for k, v in Q.items())

# plot the state-value function
plot_blackjack_values(V)

# %% [markdown]
# Finally, we visualize the policy that is estimated to be optimal.

# %%
# plot the policy
plot_policy(policy)

# %% [markdown]
# ### Alpha 0.005

# %%
# obtain the estimated optimal policy and action-value function
policy, Q = mc_control(env, 1000000, 0.005)
# Out:
# Episode 1000000/1000000.

# %%
# obtain the corresponding state-value function
V = dict((k,np.max(v)) for k, v in Q.items())

# plot the state-value function
plot_blackjack_values(V)

# %%
# plot the policy
plot_policy(policy)

# %% [markdown]
# ### Alpha 0.05

# %%
# obtain the estimated optimal policy and action-value function
policy, Q = mc_control(env, 500000, 0.05)
# Out:
# Episode 500000/500000.

# %%
# plot the policy
plot_policy(policy)

# %% [markdown]
# The **true** optimal policy $\pi_*$ can be found in Figure 5.2 of the [textbook](http://go.udacity.com/rl-textbook) (and appears below).  Compare your final estimate to the optimal policy - how close are you able to get?  If you are not happy with the performance of your algorithm, take the time to tweak the decay rate of $\epsilon$, change the value of $\alpha$, and/or run the algorithm for more episodes to attain better results.
#
# ![True Optimal Policy](images/optimal.png)
